# %%
from getData import getData
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
df = getData.createImageDf()
df
# Out:
# loading...it takes a sec
# done
#         filename  label  landscape  \
# 0      12536.jpg      0  buildings
# 1      16750.jpg      0  buildings
# 2      16988.jpg      0  buildings
# 3       4571.jpg      0  buildings
# 4      12244.jpg      0  buildings
# ...          ...    ...        ...
# 14029  14638.jpg      5     street
# 14030  15526.jpg      5     street
# 14031  18002.jpg      5     street
# 14032  10338.jpg      5     street
# 14033   8434.jpg      5     street
#
#                                              flat_arrays
# 0      [10, 6, 0, 86, 76, 51, 80, 61, 31, 85, 58, 41,...
# 1      [80, 115, 171, 81, 116, 172, 81, 116, 172, 81,...
# 2      [164, 184, 175, 158, 174, 164, 159, 174, 169, ...
# 3      [186, 193, 203, 186, 193, 203, 185, 192, 202, ...
# 4      [118, 126, 89, 99, 106, 75, 125, 127, 105, 132...
# ...                                                  ...
# 14029  [1, 12, 0, 9, 13, 16, 14, 12, 17, 22, 12, 0, 2...
# 14030  [123, 116, 123, 127, 118, 123, 146, 134, 134, ...
# 14031  [73, 96, 130, 118, 142, 170, 97, 113, 147, 149...
# 14032  [18, 57, 98, 42, 74, 112, 22, 46, 80, 20, 47, ...
# 14033  [133, 133, 125, 89, 86, 79, 92, 89, 82, 130, 1...
#
# [14034 rows x 4 columns]
