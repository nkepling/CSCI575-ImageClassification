# %% [markdown]
# # SVM

# %%
from getData import getData
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
df = getData.createImageDf()
# Out:
# loading...it takes a sec
# done

# %%
randomList = random.sample(range(0,len(df)),5) 
getData.dispImage(df.iloc[randomList])

# %%
arr = df.flat_arrays.to_numpy
